# %%
import numpy
import math as ma
import pandas as pd
import scipy.stats as ss
import matplotlib.pyplot as plt
from numpy.random import randint

# %%
# normal distribution equation: f(x) = 1/std*sqrt(2*pi)*e**1/2*(x-mean/std)**2
# standard normal distribution: f(x) = 1/sqrt(2*pi)*e**-1/2*x**2


def calc_norm(val):
    l = []
    for num in val:
        l.append(1/(np.sqrt(2*np.pi))*np.e**((-1/2)*num**2))
    return(l)

# %%
calc_norm(t)

# %%
t = randint(1,10,100)

# %%
plt.plot(calc_norm(t))

# %%
plt.plot(prob_normdist(i))

# %%
prob_normdist(i)
# Out:
# array([0.68268949, 0.72866788, 0.76986066, 0.80639903, 0.83848668,
#        0.8663856 , 0.89040142, 0.91086907, 0.92813936, 0.94256688,
#        0.95449974, 0.96427116, 0.9721931 , 0.97855178, 0.98360493,
#        0.98758067, 0.99067762, 0.99306605, 0.99488974, 0.99626837,
#        0.9973002 , 0.99806479, 0.99862572, 0.99903315, 0.99932614,
#        0.99953474, 0.99968178, 0.9997844 , 0.9998553 , 0.99990381,
#        0.99993666, 0.99995868, 0.99997331, 0.99998292, 0.99998917,
#        0.9999932 , 0.99999578, 0.9999974 , 0.99999841, 0.99999904,
#        0.99999943])

# %%
prob_normdist = lambda x: ss.norm.cdf(x) - ss.norm.cdf(-x)
